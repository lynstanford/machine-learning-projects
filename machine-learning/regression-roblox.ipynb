# %%
import yfinance as yf

rblx = yf.Ticker("RBLX")
print(rblx)
# Out:
# yfinance.Ticker object <RBLX>

# %% [markdown]
# Each column represents a different feature, for example 'High', 'Low' and 'Close' prices are all features. These features are also known as attributes, input, or predictor variables which can be used to ascertain a stock price prediction (called labels, predicted or output variables).

# %%
# get stock info
rblx.info
# Out:
# {'zip': '94403',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 960,
#  'longBusinessSummary': 'Roblox Corporation develops and operates an online entertainment platform. It offers Roblox Client, an application that allows users to explore 3D digital worlds; and Roblox Studio, a toolset that allows developers and creators to build, publish, and operate 3D experiences and other content. The company also provides Roblox Cloud, a solution that provides services and infrastructure to power the human co-experience platform. It serves customers in the United States, Canada, Europe, the Asia-Pacific, and internationally. Roblox Corporation was incorporated in 2004 and is based in San Mateo, California.',
#  'city': 'San Mateo',
#  'phone': '888 858 2569',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.corp.roblox.com',
#  'maxAge': 1,
#  'address1': '970 Park Place',
#  'industry': 'Electronic Gaming & Multimedia',
# ...

# %% [markdown]
# Retrieve historical market data

# %%
# get historical market data, here max is 35 years, but Roblox only floated on March 10, 2021.
rblx.history(period="max")
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-03-10  64.500000  74.830002  60.500000  69.500000  96268600          0
# 2021-03-11  74.930000  77.779999  70.129997  73.900002  59465900          0
# 2021-03-12  72.470001  72.959999  69.110001  69.699997  19667500          0
# 2021-03-15  70.019997  74.059998  66.250000  72.150002  19549800          0
# 2021-03-16  73.730003  78.000000  73.180000  77.000000  30216300          0
# 2021-03-17  76.029999  79.099998  74.889999  76.790001   9958200          0
# 2021-03-18  76.000000  77.000000  66.800003  67.300003   9627400          0
# 2021-03-19  69.470001  72.699997  68.080002  70.500000   6748500          0
# 2021-03-22  71.809998  72.489998  69.540001  70.000000   4238500          0
# 2021-03-23  70.099998  71.750000  67.629997  68.000000   4456000          0
# 2021-03-24  69.970001  70.000000  64.010002  64.500000   5460000          0
# ...

# %% [markdown]
# There isn't much data to work from, but I would like to create a dataframe object from the price data and try and use it to forecast future price information.

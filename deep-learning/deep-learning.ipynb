# %% [markdown]
# # Deep Learning with PythonProgramming.net
#
# I have changed values to try this deep learning tensor out. First we need to import the PyTorch package.
#
# Then to create basic tensors, or matrices, we will initiate two new variables x and y:

# %%
import torch

x = torch.Tensor([4, 2])
y = torch.Tensor([2, 3])

print(x*y)
# Out:
# tensor([8., 6.])

# %%
x = torch.zeros([4, 2])

print(x)
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
y = torch.zeros([2, 3])

print(y)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
x = torch.Tensor([4, 2])
y = torch.Tensor([2, 3])

print(x / y)
# Out:
# tensor([2.0000, 0.6667])

# %%
y = torch.rand([2, 5])
print(y)
# Out:
# tensor([[0.4410, 0.4049, 0.4833, 0.8101, 0.4760],
#         [0.3817, 0.3702, 0.9084, 0.0979, 0.9023]])

# %%
y.view([1, 10])
# Out:
# tensor([[0.4410, 0.4049, 0.4833, 0.8101, 0.4760, 0.3817, 0.3702, 0.9084, 0.0979,
#          0.9023]])

# %% [markdown]
# Re-assigning variable y

# %%
y = y.view([1,10])
y
# Out:
# tensor([[0.4410, 0.4049, 0.4833, 0.8101, 0.4760, 0.3817, 0.3702, 0.9084, 0.0979,
#          0.9023]])

# %%
import torch

x = torch.rand([2, 1])
y = torch.rand([3, 5])
z = torch.rand([1, 4])

print(x)
print(y)
print(z)
# Out:
# tensor([[0.4337],
#         [0.3248]])
# tensor([[0.1956, 0.5885, 0.8304, 0.5658, 0.2769],
#         [0.7124, 0.6349, 0.8151, 0.7650, 0.1891],
#         [0.6346, 0.1851, 0.8790, 0.2049, 0.7173]])
# tensor([[0.1927, 0.0736, 0.7841, 0.3654]])
